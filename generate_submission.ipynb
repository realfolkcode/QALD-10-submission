# %% [markdown]
# # Install and Import

# %%
# !pip install sparqlwrapper
# Out:
# Collecting sparqlwrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Collecting rdflib>=6.1.1
#   Downloading rdflib-6.1.1-py3-none-any.whl (482 kB)
#      |████████████████████████████████| 482 kB 8.2 MB/s
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 318 kB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->sparqlwrapper) (3.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->sparqlwrapper) (4.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->sparqlwrapper) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->sparqlwrapper) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->sparqlwrapper) (3.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate->rdflib>=6.1.1->sparqlwrapper) (1.15.0)
# Installing collected packages: isodate, rdflib, sparqlwrapper
# Successfully installed isodate-0.6.1 rdflib-6.1.1 sparqlwrapper-2.0.0

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

import requests
import json
import pprint

# %%
train_url = "https://raw.githubusercontent.com/KGQA/QALD_10/main/data/qald_9_plus/qald_9_plus_train_wikidata.json"
test_url = "https://raw.githubusercontent.com/KGQA/QALD_10/main/data/qald_10/qald_10.json"

# %% [markdown]
# # Utils

# %%
def read_prediction(filename):
    head_lst = []
    pred_lst = []
    tail_lst = []
    with open(filename, 'r') as f:
        for line in f:
            head, pred, tail = line.split("\t")
            head_lst.append(head)
            pred_lst.append(pred)
            tail_lst.append(tail.strip().split(' ')[0])
    return head_lst, pred_lst, tail_lst

# %%
def fb_to_wikidata(data):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

    all_answers = []
    for MIDs in data:
        answers = []
        for MID in MIDs.split(' '):
            sparql.setQuery("""
            SELECT DISTINCT ?item WHERE {
              # ?item p:P646 ?statement0.
              # ?statement0 (ps:P646)""" +  f'"/m/0{MID[3:]}".' + """
            }
            LIMIT 1
            """)
            
            sparql.setReturnFormat(JSON)
            try:
                results = sparql.query().convert()
                if results['results']['bindings']:
                    answers.append(results['results']['bindings'][0]['item']['value'])
                else:
                    answers.append(None)
            except:
                answers.append(None)
                
        all_answers.append(answers)
    return all_answers

# %% [markdown]
# # Process Predictions (Freebase)

# %% [markdown]
# Choose the corresponding file for specific language
#
# en_prediction.txt
#
# de_prediction.txt
#
# ru_prediction.txt
#
# zh_prediction.txt

# %%
heads, preds, tails = read_prediction('zh_prediction.txt')

# %%
tails
# Out:
# ['',
#  'm.0ddqw',
#  'm.01www',
#  'm.02lx2r',
#  'm.02nsjl9',
#  'm.02zsn',
#  'm.02h40lc',
#  'm.02kl65p',
#  'm.0290zjn',
#  'm.012z_m',
#  'm.09c7w0',
#  'm.01w88m0',
#  'm.06ppq',
#  'm.05vz3zq',
#  'm.0lj5',
#  'm.01ls2',
#  'm.01_d4',
#  'm.03_3d',
#  'm.09c7w0',
#  'm.0rh6k',
#  'm.09c7w0',
#  'm.0hk18',
#  'm.02lx2r',
#  'm.03czz87',
#  '',
#  'm.042_f1',
#  'm.07ssc',
#  'm.02lx2r',
#  'm.0t4ytl',
#  'm.01xrdt7',
#  'm.03fpg',
#  'm.05zppz',
#  'm.01p4vl',
#  'm.02jx1',
#  'm.07ssc',
#  'm.02b8t9',
#  'm.06yxd',
#  'm.0327fc',
#  'm.02h40lc',
#  '',
#  'm.087m22',
#  'm.02plv02',
#  'm.01xr_d2',
#  'm.0ltl7s',
#  'm.014k0b',
#  'm.053k78',
#  'm.09j_g',
#  'm.0m7gqh',
#  'm.05g12v',
#  'm.0l6nwf8',
#  'm.021y6sl',
#  'm.0cqbc',
#  'm.02_7z_',
#  'm.0d0vqn',
#  'm.048vfz',
#  'm.01y857',
#  'm.06mkj',
#  'm.0c_m3',
#  'm.0f94t',
#  'm.01rjgp',
#  'm.0bp145p',
#  'm.0377l',
#  'm.03rj0',
#  'm.043g7l',
#  'm.0kprtg',
#  'm.0nbgf',
#  'm.09c7w0',
#  'm.0l09whv',
#  'm.013kcv',
#  'm.02h40lc',
#  'm.03zbp0y',
#  'm.02d6yt',
#  'm.0dwc3wh',
#  'm.01_7r6',
#  'm.0bvc88s',
#  'm.01clyr',
#  'm.02zsn',
#  'm.0jsg3d',
#  'm.01www',
#  'm.02h6_6p',
#  'm.03m6r7l',
#  'm.05v7wt9',
#  'm.03v0t',
#  'm.085h1',
#  'm.0hzc9m5',
#  'm.01r1jx',
#  'm.078q1l',
#  'm.0p3k0f7',
#  'm.03lp48',
#  'm.03s0w',
#  'm.02jbfk',
#  'm.07ssc',
#  'm.0br23p',
#  'm.0cj16',
#  'm.0197rj',
#  'm.0dq9p',
#  'm.05zppz',
#  'm.0jmk7',
#  'm.0dwt5',
#  'm.09c7w0',
#  'm.09c7w0',
#  'm.0fb0v',
#  'm.03_9r',
#  'm.0kvp_mk',
#  'm.01xljvm',
#  '',
#  'm.04dg0x',
#  'm.09c7w0',
#  'm.015w9s',
#  'm.0dcwn',
#  'm.02vzc',
#  'm.027khfg',
#  'm.0g28c2',
#  'm.04hqz',
#  'm.0glqljb',
#  'm.02kjb_',
#  'm.01xljym',
#  'm.04jpl',
#  'm.065vqv2',
#  'm.02l96k',
#  'm.03h314x',
#  'm.02_286',
#  'm.02jbfk',
#  'm.02jbfk',
#  'm.03jvmp',
#  '',
#  'm.02lx2r',
#  'm.09glw',
#  'm.04rrx',
#  'm.0p48x',
#  'm.07ssc',
#  'm.0h66pz',
#  '',
#  'm.09c7w0',
#  'm.0g5xxgq',
#  'm.04jpl',
#  'm.01y2hnl',
#  'm.0498y',
#  'm.02j9z',
#  'm.02lx2r',
#  'm.0pxvf_',
#  'm.02lx2r',
#  'm.04w7rn',
#  'm.0cx779',
#  'm.03clk94',
#  'm.05q_mg',
#  'm.01n7',
#  '',
#  'm.0hzlz',
#  'm.0332lmn',
#  'm.09my02',
#  'm.0kyk',
#  'm.0l14md',
#  '',
#  'm.0l29yr7',
#  'm.0gkvww',
#  'm.0345h',
#  '',
#  'm.09hrc',
#  'm.02jbfk',
#  'm.02zk08',
#  'm.0zqhwt',
#  'm.02yw26',
#  'm.05qd_',
#  'm.02s7tr',
#  'm.04vpgz',
#  'm.02hyl3y',
#  'm.09c7w0',
#  'm.039_54k',
#  'm.04ztj',
#  'm.03_9r',
#  'm.09c7w0',
#  '',
#  'm.02g_6x',
#  'm.0cvkv5',
#  'm.08jnkl',
#  'm.04rky',
#  'm.0fh4n56',
#  'm.01www',
#  'm.0fq58pw',
#  'm.0hptm',
#  'm.02_ssl',
#  'm.0kpv17',
#  'm.06nm1',
#  'm.07ssc',
#  'm.01www',
#  '',
#  'm.02h40lc',
#  'm.0m77m',
#  'm.023kqy2',
#  'm.01q4ry_',
#  'm.016tw3',
#  '',
#  'm.04g51',
#  'm.01xrzlb',
#  'm.01xrdt7',
#  'm.0f2f1sz',
#  'm.0cbd2',
#  'm.0fz2vct',
#  'm.02h6_6p',
#  '',
#  'm.09c7w0',
#  'm.02_286',
#  'm.055pr',
#  'm.043008d',
#  'm.04306rv',
#  'm.0ctw_b',
#  'm.0gx_342',
#  'm.0jyw',
#  'm.06yqr8k',
#  'm.04rrx',
#  'm.02lx2r',
#  'm.0947l',
#  'm.02lx2r',
#  'm.064t9',
#  'm.0xp3db',
#  'm.059j2',
#  'm.01bntv',
#  'm.017cjb',
#  'm.0dx1j',
#  'm.0l4h_',
#  'm.0f8l9c',
#  'm.0345h',
#  'm.0xm0m9r',
#  'm.07ssc',
#  'm.07dt0m',
#  'm.02zv50',
#  'm.01xljsc',
#  'm.03jy9d',
#  'm.027hjzz',
#  'm.04lh6',
#  'm.01l89j',
#  'm.025g__',
#  'm.0y9ks',
#  'm.04n58gn',
#  'm.0m70ln1',
#  'm.0dgfsk',
#  'm.03_3d',
#  'm.0345h',
#  'm.03s0w',
#  '',
#  'm.07ssc',
#  'm.02qgqrc',
#  'm.02_j1w',
#  'm.09c7w0',
#  'm.09c7w0',
#  'm.05bnp0',
#  'm.0dbr3v',
#  'm.0345h',
#  'm.06gkkfy',
#  'm.07ssc',
#  'm.080sj1',
#  'm.0by1sn_',
#  'm.071cn',
#  'm.02822',
#  'm.0cq22mq',
#  'm.01s5nb',
#  '',
#  '',
#  'm.071cn',
#  'm.0cq246g',
#  'm.015pkc',
#  '',
#  'm.02n4kr',
#  'm.02h40lc',
#  'm.02822',
#  'm.03npn',
#  '',
#  'm.0mb5x',
#  'm.03x2bw',
#  '',
#  'm.0d060g',
#  'm.040988',
#  'm.02h40lc',
#  'm.0h7h6',
#  'm.02kdv5l',
#  'm.0345h',
#  'm.0hbpd',
#  'm.030qb3t',
#  'm.05vb0rl',
#  'm.04wgh',
#  'm.02h40lc',
#  'm.06mkj',
#  'm.02h40lc',
#  'm.013yq',
#  'm.01cx_',
#  'm.02_286',
#  'm.013xrm',
#  'm.01www',
#  'm.0f255',
#  'm.04pqqb',
#  'm.0d1226',
#  'm.04306rv',
#  'm.02lx2r',
#  'm.0q8fp1x',
#  'm.02wbm',
#  'm.0342h',
#  'm.03rk0',
#  'm.0mlwx3g',
#  'm.0345h',
#  'm.01fj8s',
#  'm.014961',
#  'm.02nb2s',
#  'm.02822',
#  'm.02slt7',
#  'm.02vx4',
#  'm.0c1rdy',
#  'm.0290ngj',
#  'm.09c7w0',
#  'm.03h64',
#  'm.0162wz',
#  'm.02822',
#  'm.045zx6v',
#  'm.09jd9nh',
#  'm.02h40lc',
#  'm.0dh1n_',
#  'm.03rk0',
#  'm.01h175p',
#  'm.01xryvm',
#  'm.041h0',
#  'm.0735l',
#  'm.02lx2r',
#  'm.064r2r',
#  'm.02lx2r',
#  'm.05_xw',
#  'm.09c7w0',
#  'm.05y49',
#  'm.067t4w',
#  'm.058yxt',
#  'm.0h6jx7g',
#  'm.01xljym',
#  'm.02lx2r',
#  'm.0475q',
#  'm.04w2q5q',
#  'm.02p3rv1',
#  'm.01tp5bj',
#  'm.03rt9',
#  'm.051fsz1',
#  'm.0kpv1_',
#  'm.05hk5pv',
#  'm.04znx',
#  'm.07ssc',
#  'm.03y03j',
#  'm.09c7w0',
#  'm.02h6fbs',
#  'm.0_gvffr',
#  '',
#  'm.01d5z6',
#  'm.0gnm9v8',
#  'm.07472s',
#  'm.0400v3',
#  'm.02822',
#  'm.04fnrhx',
#  'm.06c62',
#  'm.01xrrch',
#  'm.03_3d',
#  'm.06qd3',
#  'm.0f1nc2h',
#  'm.0m7yy',
#  'm.0jt_x',
#  'm.03yws9v',
#  'm.0jgd',
#  'm.0lsxr',
#  'm.06n3y',
#  'm.014mlp',
#  'm.0jsg3d',
#  'm.02bh_v',
#  'm.01nyx5k',
#  'm.0cr3d',
#  'm.02nzb8',
#  'm.0345h',
#  'm.08tjm1',
#  'm.03gdzw',
#  'm.04vr_f',
#  'm.0f8l9c',
#  'm.0jsg2m',
#  'm.01mw0wq',
#  'm.02h40lc',
#  'm.02pq140',
#  'm.0147s_',
#  'm.02nmm_l',
#  'm.02hwhyv',
#  'm.0_frm',
#  'm.01xp01',
#  'm.0j8g6',
#  'm.01yb09',
#  'm.07t90',
#  'm.09949m',
#  'm.02m77',
#  'm.09c7w0',
#  'm.0l5r18',
#  'm.03_3d',
#  'm.014j1m',
#  'm.0pxlngs']

# %%
print('Len heads:', len(heads))
print('Len preds:', len(preds))
print('Len tails:', len(tails))
# Out:
# Len heads: 394
# Len preds: 394
# Len tails: 394

# %%
answers = fb_to_wikidata(tails)

# %%
answers
# Out:
# [[None],
#  ['http://www.wikidata.org/entity/Q51797'],
#  ['http://www.wikidata.org/entity/Q34467'],
#  ['http://www.wikidata.org/entity/Q482994'],
#  [None],
#  ['http://www.wikidata.org/entity/Q43445'],
#  ['http://www.wikidata.org/entity/Q1860'],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q212431'],
#  ['http://www.wikidata.org/entity/Q30'],
#  ['http://www.wikidata.org/entity/Q712624'],
#  ['http://www.wikidata.org/entity/Q226730'],
#  ['http://www.wikidata.org/entity/Q15180'],
#  ['http://www.wikidata.org/entity/Q214132'],
#  ['http://www.wikidata.org/entity/Q739'],
#  ['http://www.wikidata.org/entity/Q1297'],
#  ['http://www.wikidata.org/entity/Q17'],
#  ['http://www.wikidata.org/entity/Q30'],
#  ['http://www.wikidata.org/entity/Q61'],
#  ['http://www.wikidata.org/entity/Q30'],
#  [None],
#  ['http://www.wikidata.org/entity/Q482994'],
#  ['http://www.wikidata.org/entity/Q28856068'],
#  [None],
#  ['http://www.wikidata.org/entity/Q7039258'],
#  ['http://www.wikidata.org/entity/Q145'],
#  ['http://www.wikidata.org/entity/Q482994'],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q846662'],
#  ['http://www.wikidata.org/entity/Q44148'],
#  ['http://www.wikidata.org/entity/Q164782'],
#  ['http://www.wikidata.org/entity/Q21'],
#  ['http://www.wikidata.org/entity/Q145'],
#  ['http://www.wikidata.org/entity/Q311439'],
#  ['http://www.wikidata.org/entity/Q1456'],
#  ['http://www.wikidata.org/entity/Q154849'],
#  ['http://www.wikidata.org/entity/Q1860'],
#  [None],
#  ['http://www.wikidata.org/entity/Q275167'],
#  [None],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q134556'],
#  ['http://www.wikidata.org/entity/Q756320'],
#  ['http://www.wikidata.org/entity/Q200491'],
#  [None],
#  ['http://www.wikidata.org/entity/Q1198033'],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q2179'],
#  ['http://www.wikidata.org/entity/Q621231'],
#  ['http://www.wikidata.org/entity/Q34'],
#  ['http://www.wikidata.org/entity/Q829643'],
#  ['http://www.wikidata.org/entity/Q157171'],
#  ['http://www.wikidata.org/entity/Q29'],
#  ['http://www.wikidata.org/entity/Q16563'],
#  ['http://www.wikidata.org/entity/Q189074'],
#  ['http://www.wikidata.org/entity/Q51747'],
#  [None],
#  ['http://www.wikidata.org/entity/Q45875'],
#  ['http://www.wikidata.org/entity/Q189'],
#  ['http://www.wikidata.org/entity/Q56760250'],
#  [None],
#  ['http://www.wikidata.org/entity/Q124184'],
#  ['http://www.wikidata.org/entity/Q30'],
#  [None],
#  ['http://www.wikidata.org/entity/Q44989'],
#  ['http://www.wikidata.org/entity/Q1860'],
#  [None],
#  ['http://www.wikidata.org/entity/Q1047918'],
#  [None],
#  ['http://www.wikidata.org/entity/Q1643563'],
#  [None],
#  ['http://www.wikidata.org/entity/Q155152'],
#  ['http://www.wikidata.org/entity/Q43445'],
#  [None],
#  ['http://www.wikidata.org/entity/Q34467'],
#  ['http://www.wikidata.org/entity/Q1726'],
#  ['http://www.wikidata.org/entity/Q7757059'],
#  [None],
#  ['http://www.wikidata.org/entity/Q1204'],
#  ['http://www.wikidata.org/entity/Q7825'],
#  [None],
#  ['http://www.wikidata.org/entity/Q464650'],
#  ['http://www.wikidata.org/entity/Q561963'],
#  [None],
#  ['http://www.wikidata.org/entity/Q706878'],
#  ['http://www.wikidata.org/entity/Q1546'],
#  ['http://www.wikidata.org/entity/Q222910'],
#  ['http://www.wikidata.org/entity/Q145'],
#  ['http://www.wikidata.org/entity/Q1276340'],
#  ['http://www.wikidata.org/entity/Q226528'],
#  ['http://www.wikidata.org/entity/Q1241754'],
#  ['http://www.wikidata.org/entity/Q12192'],
#  ['http://www.wikidata.org/entity/Q44148'],
#  ['http://www.wikidata.org/entity/Q121783'],
#  ['http://www.wikidata.org/entity/Q206987'],
#  ['http://www.wikidata.org/entity/Q30'],
#  ['http://www.wikidata.org/entity/Q30'],
#  ['http://www.wikidata.org/entity/Q212699'],
#  ['http://www.wikidata.org/entity/Q5287'],
#  [None],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q1065095'],
#  ['http://www.wikidata.org/entity/Q30'],
#  ['http://www.wikidata.org/entity/Q506240'],
#  ['http://www.wikidata.org/entity/Q850275'],
#  ['http://www.wikidata.org/entity/Q33'],
#  ['http://www.wikidata.org/entity/Q49764'],
#  ['http://www.wikidata.org/entity/Q4385786'],
#  ['http://www.wikidata.org/entity/Q822'],
#  ['http://www.wikidata.org/entity/Q5344596'],
#  ['http://www.wikidata.org/entity/Q8386'],
#  [None],
#  ['http://www.wikidata.org/entity/Q84'],
#  [None],
#  ['http://www.wikidata.org/entity/Q236932'],
#  [None],
#  ['http://www.wikidata.org/entity/Q60'],
#  ['http://www.wikidata.org/entity/Q222910'],
#  ['http://www.wikidata.org/entity/Q222910'],
#  ['http://www.wikidata.org/entity/Q662081'],
#  [None],
#  ['http://www.wikidata.org/entity/Q482994'],
#  ['http://www.wikidata.org/entity/Q5451'],
#  ['http://www.wikidata.org/entity/Q1166'],
#  ['http://www.wikidata.org/entity/Q507000'],
#  ['http://www.wikidata.org/entity/Q145'],
#  ['http://www.wikidata.org/entity/Q2296093'],
#  [None],
#  ['http://www.wikidata.org/entity/Q30'],
#  [None],
#  ['http://www.wikidata.org/entity/Q84'],
#  [None],
#  ['http://www.wikidata.org/entity/Q1603'],
#  ['http://www.wikidata.org/entity/Q46'],
#  ['http://www.wikidata.org/entity/Q482994'],
#  [None],
#  ['http://www.wikidata.org/entity/Q482994'],
#  ['http://www.wikidata.org/entity/Q637021'],
#  ['http://www.wikidata.org/entity/Q1049625'],
#  ['http://www.wikidata.org/entity/Q608565'],
#  ['http://www.wikidata.org/entity/Q4115716'],
#  ['http://www.wikidata.org/entity/Q17334923'],
#  [None],
#  ['http://www.wikidata.org/entity/Q258'],
#  [None],
#  ['http://www.wikidata.org/entity/Q435326'],
#  ['http://www.wikidata.org/entity/Q482980'],
#  ['http://www.wikidata.org/entity/Q133163'],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q7801499'],
#  ['http://www.wikidata.org/entity/Q183'],
#  [None],
#  ['http://www.wikidata.org/entity/Q1206'],
#  ['http://www.wikidata.org/entity/Q222910'],
#  ['http://www.wikidata.org/entity/Q1351911'],
#  [None],
#  ['http://www.wikidata.org/entity/Q465978'],
#  ['http://www.wikidata.org/entity/Q159846'],
#  ['http://www.wikidata.org/entity/Q1326154'],
#  ['http://www.wikidata.org/entity/Q1359740'],
#  [None],
#  ['http://www.wikidata.org/entity/Q30'],
#  [None],
#  ['http://www.wikidata.org/entity/Q8445'],
#  ['http://www.wikidata.org/entity/Q5287'],
#  ['http://www.wikidata.org/entity/Q30'],
#  [None],
#  ['http://www.wikidata.org/entity/Q918224'],
#  ['http://www.wikidata.org/entity/Q209667'],
#  ['http://www.wikidata.org/entity/Q5469141'],
#  ['http://www.wikidata.org/entity/Q7377'],
#  [None],
#  ['http://www.wikidata.org/entity/Q34467'],
#  [None],
#  ['http://www.wikidata.org/entity/Q25395'],
#  ['http://www.wikidata.org/entity/Q222052'],
#  [None],
#  ['http://www.wikidata.org/entity/Q1321'],
#  ['http://www.wikidata.org/entity/Q145'],
#  ['http://www.wikidata.org/entity/Q34467'],
#  [None],
#  ['http://www.wikidata.org/entity/Q1860'],
#  ['http://www.wikidata.org/entity/Q40874'],
#  [None],
#  ['http://www.wikidata.org/entity/Q8041698'],
#  ['http://www.wikidata.org/entity/Q168383'],
#  [None],
#  ['http://www.wikidata.org/entity/Q8242'],
#  ['http://www.wikidata.org/entity/Q21191270'],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q36180'],
#  [None],
#  ['http://www.wikidata.org/entity/Q1726'],
#  [None],
#  ['http://www.wikidata.org/entity/Q30'],
#  ['http://www.wikidata.org/entity/Q60'],
#  ['http://www.wikidata.org/entity/Q81225'],
#  [None],
#  ['http://www.wikidata.org/entity/Q188'],
#  ['http://www.wikidata.org/entity/Q664'],
#  ['http://www.wikidata.org/entity/Q4759455'],
#  ['http://www.wikidata.org/entity/Q3640'],
#  [None],
#  ['http://www.wikidata.org/entity/Q1166'],
#  ['http://www.wikidata.org/entity/Q482994'],
#  ['http://www.wikidata.org/entity/Q490'],
#  ['http://www.wikidata.org/entity/Q482994'],
#  ['http://www.wikidata.org/entity/Q37073'],
#  [None],
#  ['http://www.wikidata.org/entity/Q55'],
#  ['http://www.wikidata.org/entity/Q8167'],
#  ['http://www.wikidata.org/entity/Q134902'],
#  ['http://www.wikidata.org/entity/Q3957'],
#  ['http://www.wikidata.org/entity/Q459435'],
#  ['http://www.wikidata.org/entity/Q142'],
#  ['http://www.wikidata.org/entity/Q183'],
#  [None],
#  ['http://www.wikidata.org/entity/Q145'],
#  ['http://www.wikidata.org/entity/Q2562301'],
#  ['http://www.wikidata.org/entity/Q1210800'],
#  [None],
#  ['http://www.wikidata.org/entity/Q420054'],
#  ['http://www.wikidata.org/entity/Q2549663'],
#  ['http://www.wikidata.org/entity/Q24826'],
#  ['http://www.wikidata.org/entity/Q231618'],
#  ['http://www.wikidata.org/entity/Q131578'],
#  ['http://www.wikidata.org/entity/Q3460228'],
#  ['http://www.wikidata.org/entity/Q3342247'],
#  [None],
#  ['http://www.wikidata.org/entity/Q205230'],
#  ['http://www.wikidata.org/entity/Q17'],
#  ['http://www.wikidata.org/entity/Q183'],
#  ['http://www.wikidata.org/entity/Q1546'],
#  [None],
#  ['http://www.wikidata.org/entity/Q145'],
#  [None],
#  ['http://www.wikidata.org/entity/Q336286'],
#  ['http://www.wikidata.org/entity/Q30'],
#  ['http://www.wikidata.org/entity/Q30'],
#  ['http://www.wikidata.org/entity/Q306403'],
#  ['http://www.wikidata.org/entity/Q268166'],
#  ['http://www.wikidata.org/entity/Q183'],
#  [None],
#  ['http://www.wikidata.org/entity/Q145'],
#  ['http://www.wikidata.org/entity/Q5201118'],
#  ['http://www.wikidata.org/entity/Q642878'],
#  ['http://www.wikidata.org/entity/Q128069'],
#  ['http://www.wikidata.org/entity/Q25372'],
#  [None],
#  ['http://www.wikidata.org/entity/Q426316'],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q128069'],
#  [None],
#  ['http://www.wikidata.org/entity/Q165524'],
#  [None],
#  ['http://www.wikidata.org/entity/Q6585139'],
#  ['http://www.wikidata.org/entity/Q1860'],
#  ['http://www.wikidata.org/entity/Q25372'],
#  ['http://www.wikidata.org/entity/Q193606'],
#  [None],
#  ['http://www.wikidata.org/entity/Q41042'],
#  ['http://www.wikidata.org/entity/Q1455105'],
#  [None],
#  ['http://www.wikidata.org/entity/Q16'],
#  ['http://www.wikidata.org/entity/Q42381'],
#  ['http://www.wikidata.org/entity/Q1860'],
#  ['http://www.wikidata.org/entity/Q172'],
#  ['http://www.wikidata.org/entity/Q188473'],
#  ['http://www.wikidata.org/entity/Q183'],
#  ['http://www.wikidata.org/entity/Q210877'],
#  ['http://www.wikidata.org/entity/Q65'],
#  [None],
#  ['http://www.wikidata.org/entity/Q1028'],
#  ['http://www.wikidata.org/entity/Q1860'],
#  ['http://www.wikidata.org/entity/Q29'],
#  ['http://www.wikidata.org/entity/Q1860'],
#  ['http://www.wikidata.org/entity/Q23556'],
#  ['http://www.wikidata.org/entity/Q100'],
#  ['http://www.wikidata.org/entity/Q60'],
#  ['http://www.wikidata.org/entity/Q42884'],
#  ['http://www.wikidata.org/entity/Q34467'],
#  ['http://www.wikidata.org/entity/Q1076968'],
#  ['http://www.wikidata.org/entity/Q697131'],
#  ['http://www.wikidata.org/entity/Q1209933'],
#  ['http://www.wikidata.org/entity/Q188'],
#  ['http://www.wikidata.org/entity/Q482994'],
#  [None],
#  ['http://www.wikidata.org/entity/Q2095'],
#  ['http://www.wikidata.org/entity/Q6607'],
#  ['http://www.wikidata.org/entity/Q668'],
#  [None],
#  ['http://www.wikidata.org/entity/Q183'],
#  ['http://www.wikidata.org/entity/Q1412298'],
#  ['http://www.wikidata.org/entity/Q194290'],
#  ['http://www.wikidata.org/entity/Q318249'],
#  ['http://www.wikidata.org/entity/Q25372'],
#  ['http://www.wikidata.org/entity/Q1032540'],
#  ['http://www.wikidata.org/entity/Q2736'],
#  ['http://www.wikidata.org/entity/Q3046481'],
#  [None],
#  ['http://www.wikidata.org/entity/Q30'],
#  ['http://www.wikidata.org/entity/Q8646'],
#  ['http://www.wikidata.org/entity/Q80900'],
#  ['http://www.wikidata.org/entity/Q25372'],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q1860'],
#  ['http://www.wikidata.org/entity/Q276130'],
#  ['http://www.wikidata.org/entity/Q668'],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q892'],
#  ['http://www.wikidata.org/entity/Q220499'],
#  ['http://www.wikidata.org/entity/Q482994'],
#  ['http://www.wikidata.org/entity/Q7895215'],
#  ['http://www.wikidata.org/entity/Q482994'],
#  ['http://www.wikidata.org/entity/Q192488'],
#  ['http://www.wikidata.org/entity/Q30'],
#  ['http://www.wikidata.org/entity/Q81571'],
#  ['http://www.wikidata.org/entity/Q17004870'],
#  ['http://www.wikidata.org/entity/Q1752259'],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q482994'],
#  ['http://www.wikidata.org/entity/Q172763'],
#  [None],
#  ['http://www.wikidata.org/entity/Q1783093'],
#  ['http://www.wikidata.org/entity/Q491252'],
#  ['http://www.wikidata.org/entity/Q27'],
#  [None],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q163087'],
#  ['http://www.wikidata.org/entity/Q145'],
#  ['http://www.wikidata.org/entity/Q683785'],
#  ['http://www.wikidata.org/entity/Q30'],
#  ['http://www.wikidata.org/entity/Q4964182'],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q294625'],
#  [None],
#  ['http://www.wikidata.org/entity/Q2224610'],
#  ['http://www.wikidata.org/entity/Q705531'],
#  ['http://www.wikidata.org/entity/Q25372'],
#  [None],
#  ['http://www.wikidata.org/entity/Q220'],
#  [None],
#  ['http://www.wikidata.org/entity/Q17'],
#  ['http://www.wikidata.org/entity/Q884'],
#  [None],
#  ['http://www.wikidata.org/entity/Q838121'],
#  ['http://www.wikidata.org/entity/Q173626'],
#  [None],
#  ['http://www.wikidata.org/entity/Q414'],
#  ['http://www.wikidata.org/entity/Q208505'],
#  ['http://www.wikidata.org/entity/Q18'],
#  ['http://www.wikidata.org/entity/Q1765120'],
#  [None],
#  ['http://www.wikidata.org/entity/Q79800'],
#  ['http://www.wikidata.org/entity/Q444832'],
#  ['http://www.wikidata.org/entity/Q18419'],
#  ['http://www.wikidata.org/entity/Q193592'],
#  ['http://www.wikidata.org/entity/Q183'],
#  ['http://www.wikidata.org/entity/Q333353'],
#  ['http://www.wikidata.org/entity/Q672543'],
#  ['http://www.wikidata.org/entity/Q172975'],
#  ['http://www.wikidata.org/entity/Q142'],
#  [None],
#  [None],
#  ['http://www.wikidata.org/entity/Q1860'],
#  ['http://www.wikidata.org/entity/Q7928436'],
#  ['http://www.wikidata.org/entity/Q3297878'],
#  [None],
#  ['http://www.wikidata.org/entity/Q9176'],
#  ['http://www.wikidata.org/entity/Q1134176'],
#  ['http://www.wikidata.org/entity/Q25923'],
#  ['http://www.wikidata.org/entity/Q49615'],
#  ['http://www.wikidata.org/entity/Q1516734'],
#  ['http://www.wikidata.org/entity/Q219563'],
#  ['http://www.wikidata.org/entity/Q406'],
#  ['http://www.wikidata.org/entity/Q23436'],
#  ['http://www.wikidata.org/entity/Q30'],
#  [None],
#  ['http://www.wikidata.org/entity/Q17'],
#  ['http://www.wikidata.org/entity/Q89'],
#  [None]]

# %%
f = requests.get(test_url)
data_test = json.loads(f.text)

# %%
data_test['questions'][0]
# Out:
# {'aggregation': False,
#  'answers': [{'head': {'vars': ['result']},
#    'results': {'bindings': [{'result': {'type': 'uri',
#        'value': 'http://www.wikidata.org/entity/Q42299'}}]}}],
#  'id': 0,
#  'query': {'sparql': 'PREFIX bd: <http://www.bigdata.com/rdf#> PREFIX dct: <http://purl.org/dc/terms/> PREFIX geo: <http://www.opengis.net/ont/geosparql#> PREFIX p: <http://www.wikidata.org/prop/> PREFIX pq: <http://www.wikidata.org/prop/qualifier/> PREFIX ps: <http://www.wikidata.org/prop/statement/> PREFIX psn: <http://www.wikidata.org/prop/statement/value-normalized/> PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX wd: <http://www.wikidata.org/entity/> PREFIX wds: <http://www.wikidata.org/entity/statement/> PREFIX wdt: <http://www.wikidata.org/prop/direct/> PREFIX wdv: <http://www.wikidata.org/value/> PREFIX wikibase: <http://wikiba.se/ontology#> PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> SELECT DISTINCT ?result WHERE { wd:Q761383 wdt:P138 ?result. }'},
#  'question': [{'language': 'en',
#    'string': 'After whom is the Riemannian geometry named?'},
#   {'language': 'zh', 'string': '黎曼几何是以谁命名的？'},
#   {'language': 'de',
#    'string': 'Nach wem ist die Riemannsche Geometrie benannt?'},
#   {'language': 'ru', 'string': 'В честь кого названа риманова геометрия ?'}]}

# %%
for item in data_test['questions']:
    del item['answers']
    del item['aggregation']
    del item['query']

# %%
data_test['questions'][0]
# Out:
# {'id': 0,
#  'question': [{'language': 'en',
#    'string': 'After whom is the Riemannian geometry named?'},
#   {'language': 'zh', 'string': '黎曼几何是以谁命名的？'},
#   {'language': 'de',
#    'string': 'Nach wem ist die Riemannsche Geometrie benannt?'},
#   {'language': 'ru', 'string': 'В честь кого названа риманова геометрия ?'}]}

# %%
for i, item in enumerate(data_test['questions']):
    item['aggregation'] = False
    head_dict = {"vars": ["result"]}
    results_dict = {"bindings": [{"result": {"type": "uri", "value": answers[i][0]}}]}
    item['answers'] = [{"head": head_dict,
                        "results": results_dict}]

# %%
data_test['questions'][0]
# Out:
# {'aggregation': False,
#  'answers': [{'head': {'vars': ['result']},
#    'results': {'bindings': [{'result': {'type': 'uri', 'value': None}}]}}],
#  'id': 0,
#  'question': [{'language': 'en',
#    'string': 'After whom is the Riemannian geometry named?'},
#   {'language': 'zh', 'string': '黎曼几何是以谁命名的？'},
#   {'language': 'de',
#    'string': 'Nach wem ist die Riemannsche Geometrie benannt?'},
#   {'language': 'ru', 'string': 'В честь кого названа риманова геометрия ?'}]}

# %%
with open("prediction.json", "w") as outfile:
    json.dump(data_test, outfile)

# %% [markdown]
# # Process Predictions (Wikidata)

# %%
answers = []
with open('zh_id_answers.txt', 'r') as f:
    for line in f:
        s = line.strip()
        if len(s) < 1:
            s = ' '
        answers.append(s)

# %%
answers
# Out:
# ['http://www.wikidata.org/entity/Q42299',
#  'http://www.wikidata.org/entity/Q667465',
#  'http://www.wikidata.org/entity/Q1676929',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q227965',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q65837091',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q121180',
#  ' ',
#  'http://www.wikidata.org/entity/Q4661471',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '64858754',
#  ' ',
#  'http://www.wikidata.org/entity/Q190076',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q5237440',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  '1',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  '1',
#  'http://www.wikidata.org/entity/Q1280917',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '2',
#  ' ',
#  ' ',
#  '1',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  '2',
#  ' ',
#  ' ',
#  ' ',
#  '3',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  '1',
#  '1',
#  ' ',
#  'http://www.wikidata.org/entity/Q96090149',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  '1',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q5082829',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q24856246',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q7362960',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q97067050',
#  'http://www.wikidata.org/entity/Q99955102',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q2748506',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q1645137',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  '1',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q7920465',
#  ' ',
#  '1',
#  'http://www.wikidata.org/entity/Q1232954',
#  'http://www.wikidata.org/entity/Q3181863',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q1215220',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q37946917',
#  ' ',
#  'http://www.wikidata.org/entity/Q3646297',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q55176578',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q47120382',
#  ' ',
#  '1',
#  'http://www.wikidata.org/entity/Q7411777',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q1983102',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q94381320',
#  'http://www.wikidata.org/entity/Q438564',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q95745916',
#  'http://www.wikidata.org/entity/Q182021',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q103955',
#  '1',
#  ' ',
#  ' ',
#  '1',
#  'http://www.wikidata.org/entity/Q1279374',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q262582',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q716706',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q5083414',
#  ' ',
#  ' ',
#  ' ',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q7362960',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q7411777',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '1979',
#  'http://www.wikidata.org/entity/Q1892831',
#  '81752000',
#  'http://www.wikidata.org/entity/Q16011261',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q45450589',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q17410449',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q233619',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q37946917',
#  ' ',
#  'http://www.wikidata.org/entity/Q55428',
#  ' ',
#  'http://www.wikidata.org/entity/Q708544',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q3308269',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q353023',
#  ' ',
#  'http://www.wikidata.org/entity/Q1631816',
#  ' ',
#  'http://www.wikidata.org/entity/Q2870616',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q381884',
#  'http://www.wikidata.org/entity/Q181900',
#  ' ',
#  'http://www.wikidata.org/entity/Q4341361',
#  'http://www.wikidata.org/entity/Q2263186',
#  'http://www.wikidata.org/entity/Q176409',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'http://www.wikidata.org/entity/Q12382',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  '2',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '7',
#  '3',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  ' ',
#  'http://www.wikidata.org/entity/Q3927850']

# %%
data_test['questions'][0]
# Out:
# {'aggregation': False,
#  'answers': [{'head': {'vars': ['result']},
#    'results': {'bindings': [{'result': {'type': 'uri',
#        'value': 'http://www.wikidata.org/entity/Q15416'}}]}}],
#  'id': 0,
#  'question': [{'language': 'en',
#    'string': 'After whom is the Riemannian geometry named?'},
#   {'language': 'zh', 'string': '黎曼几何是以谁命名的？'},
#   {'language': 'de',
#    'string': 'Nach wem ist die Riemannsche Geometrie benannt?'},
#   {'language': 'ru', 'string': 'В честь кого названа риманова геометрия ?'}]}

# %%
for i, item in enumerate(data_test['questions']):
    if answers[i][0] != ' ':
        item['aggregation'] = False
        head_dict = {"vars": ["result"]}
        results_dict = {"bindings": [{"result": {"type": "uri", "value": answers[i][0]}}]}
        item['answers'] = [{"head": head_dict,
                            "results": results_dict}]
    elif answers[i][0].isnumeric():
        item['aggregation'] = False
        head_dict = {"vars": ["result"]}
        results_dict = {"bindings": [{"result": {"datatype": "http://www.w3.org/2001/XMLSchema#integer", "type": "literal", "value": answers[i][0]}}]}
        item['answers'] = [{"head": head_dict,
                            "results": results_dict}]

# %%
data_test['questions'][14]
# Out:
# {'aggregation': False,
#  'answers': [{'head': {'vars': ['result']},
#    'results': {'bindings': [{'result': {'type': 'uri', 'value': None}}]}}],
#  'id': 14,
#  'question': [{'language': 'en',
#    'string': 'How many different presidents of Russia have there been that took the position after 1990?'},
#   {'language': 'zh', 'string': '在1990年后俄罗斯有多少任总统？'},
#   {'language': 'de',
#    'string': 'Wieviele unterschiedliche Präsident:innen Russlands haben seit 1990 das Amt angetreten?'},
#   {'language': 'ru',
#    'string': 'Сколько было разных президентов России, занимавших этот пост после 1990 года?'}]}

# %%
with open("zh_ensemble_prediction_3.json", "w") as outfile:
    json.dump(data_test, outfile)
